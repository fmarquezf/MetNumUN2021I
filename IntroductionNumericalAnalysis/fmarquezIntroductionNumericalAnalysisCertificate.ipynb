# %% [markdown]
# <a href="https://colab.research.google.com/github/fmarquezf/MetNumUN2021I/blob/main/IntroductionNumericalAnalysis/fmarquezIntroductionNumericalAnalysisCertificate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# linkedin.com/in/fabian-marquez-a8b364212
